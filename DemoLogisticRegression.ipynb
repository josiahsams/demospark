% %%
data=load('/Users/josiahsams/Desktop/rawdata');

% %%
rndIDX = randperm(size(data,1)); 
data(rndIDX(1:5),:)
% Out:
% ans =
%
%    0.738064  -1.469778  -1.000000
%   -0.098845  -1.504528  -1.000000
%    2.162062   1.464016   1.000000
%    0.248987  -0.691669   1.000000
%   -0.588867  -0.489406  -1.000000

% %%
X=data(:,1:2);
Y=data(:,3);

% %%
size(X)
size(Y)
% Out:
% ans =
%
%    100     2
%
% ans =
%
%    100     1

% %%
pos=find(Y == 1);
neg=find(Y == -1);

% %%
figure; hold on;
plot(X(pos, 1), X(pos, 2), 'k+','LineWidth', 2, 'MarkerSize', 7);
plot(X(neg, 1), X(neg, 2), 'ko', 'MarkerFaceColor', 'y','MarkerSize', 7);
hold off;

% %%
dataI=load('/Users/josiahsams/Desktop/rawinputdata');
hist(dataI, 20)

% %%
plot_x = [min(X(:,1))-2,  max(X(:,1))+2];
theta=[-23.520847587836172, 17.397301833575906, 21.913091272856963]
plot_y = (-1./theta(3)).*(theta(2).*plot_x + theta(1));
% Out:
% theta =
%
%   -23.521   17.397   21.913

% %%
figure; hold on;
plot(X(pos, 1), X(pos, 2), 'k+','LineWidth', 2, 'MarkerSize', 7);
plot(X(neg, 1), X(neg, 2), 'ko', 'MarkerFaceColor', 'y','MarkerSize', 7);
plot(plot_x, plot_y)
hold off;
